# %% [markdown]
# # Notebook designed to test PERT class methods (Model 1)

# %%
import sys, os
sys.path.insert(0, '../../../src/CPM/')
sys.path.insert(0,'../../../../')

from PertMain2 import Pert, Activity
import copy
from datetime import datetime, time
import json
# Out:
# WARNING: "/Users/mandd/projects/LOGOS/src/contrib" already in system path. Skipping setup
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:22
#      21 try:
# ---> 22   from LOGOS.src.CapitalInvestments.PyomoModels.PySPBase import PySPBase
#      23   from LOGOS.src.CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/SingleKnapsack.py:23
#      22 try:
# ---> 23   from LOGOS.src.CapitalInvestments.PyomoModels.KnapsackBase import KnapsackBase
#      24 except ImportError:
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:25
#      24 except ImportError:
# ---> 25   from .PySPBase import PySPBase
#      26   from CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:22
#      21 try:
# ---> 22   from LOGOS.src.CapitalInvestments.PyomoModels.PySPBase import PySPBase
#      23   from LOGOS.src.CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/__init__.py:9
#       8 try:
# ----> 9   from LOGOS.src.CapitalInvestments.PyomoModels.SingleKnapsack import SingleKnapsack
#      10   from LOGOS.src.CapitalInvestments.PyomoModels.MultipleKnapsack import MultipleKnapsack
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/SingleKnapsack.py:25
#      24 except ImportError:
# ---> 25   from .KnapsackBase import KnapsackBase
#      26 #Internal Modules End--------------------------------------------------------------------------------
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:25
#      24 except ImportError:
# ---> 25   from .PySPBase import PySPBase
#      26   from CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:22
#      21 try:
# ---> 22   from LOGOS.src.CapitalInvestments.PyomoModels.PySPBase import PySPBase
#      23   from LOGOS.src.CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/SingleKnapsack.py:23
#      22 try:
# ---> 23   from LOGOS.src.CapitalInvestments.PyomoModels.KnapsackBase import KnapsackBase
#      24 except ImportError:
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:25
#      24 except ImportError:
# ---> 25   from .PySPBase import PySPBase
#      26   from CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:22
#      21 try:
# ---> 22   from LOGOS.src.CapitalInvestments.PyomoModels.PySPBase import PySPBase
#      23   from LOGOS.src.CapitalInvestments.investment_utils import investmentUtils as utils
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:21
#      20 try:
# ---> 21   import pyomo.pysp.util.rapper as rapper
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pyomo/common/deprecation.py:622, in MovedModuleLoader.create_module(self, spec)
#     621     return sys.modules[self._info.new_name]
# --> 622 return importlib.import_module(self._info.new_name)
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#
# ModuleNotFoundError: No module named 'pyutilib'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 sys.path.insert(0, '../../../src/CPM/')
#       3 sys.path.insert(0,'../../../../')
# ----> 5 from PertMain2 import Pert, Activity
#       6 import copy
#       7 from datetime import datetime, time
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../src/CPM/PertMain2.py:21
#      18 import json
#      20 #from MDKoutage import mdkChoiceModel
# ---> 21 from LOGOS.src.CPM import MDKoutage
#      24 class Activity:
#      25   """
#      26     This is the base class for a single activity
#      27     Extended from the original development of Nofar Alfasi
#      28     Source https://github.com/nofaralfasi/PERT-CPM-graph
#      29   """
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/__init__.py:8
#       1 # Copyright 2020, Battelle Energy Alliance, LLC
#       2 # ALL RIGHTS RESERVED
#       3 """
#       4 Created on Nov. 18, 2019
#       5 @author: wangc, mandd
#       6 """
# ----> 8 from LOGOS.src import CapitalInvestmentModel
#       9 from LOGOS.src import BatteryReplacementCashFlowModel
#      10 from LOGOS.src import IncrementalNPV
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestmentModel.py:25
#      23 else:
#      24   sys.path.append(os.path.join(pluginLoc, 'src', 'contrib'))
# ---> 25 from LOGOS.src.CapitalInvestments import PyomoModels
#      26 from LOGOS.src.CapitalInvestments.investment_utils import inputReader
#      27 #Internal Modules End--------------------------------------------------------------------------------
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/__init__.py:26
#      24   from LOGOS.src.CapitalInvestments.PyomoModels.Factory import knownTypes, returnInstance, returnClass
#      25 except ImportError:
# ---> 26   from .SingleKnapsack import SingleKnapsack
#      27   from .MultipleKnapsack import MultipleKnapsack
#      28   from .MCKP import MCKP
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/SingleKnapsack.py:25
#      23   from LOGOS.src.CapitalInvestments.PyomoModels.KnapsackBase import KnapsackBase
#      24 except ImportError:
# ---> 25   from .KnapsackBase import KnapsackBase
#      26 #Internal Modules End--------------------------------------------------------------------------------
#      28 logger = logging.getLogger(__name__)
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/KnapsackBase.py:25
#      23   from LOGOS.src.CapitalInvestments.investment_utils import investmentUtils as utils
#      24 except ImportError:
# ---> 25   from .PySPBase import PySPBase
#      26   from CapitalInvestments.investment_utils import investmentUtils as utils
#      27 #Internal Modules End--------------------------------------------------------------------------------
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../../LOGOS/src/CapitalInvestments/PyomoModels/PySPBase.py:24
#      22   from pyomo.pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#      23 except ImportError:
# ---> 24   import pysp.util.rapper as rapper
#      25   from pysp.scenariotree.tree_structure_model import CreateAbstractScenarioTreeModel
#      26 #External Modules End--------------------------------------------------------------------------------
#      27
#      28 #Internal Modules------------------------------------------------------------------------------------
#
# File ~/projects/LOGOS/src/contrib/pysp/__init__.py:16
#      13 from pyomo.common.plugin import PluginGlobals
#      14 PluginGlobals.add_env("pyomo")
# ---> 16 import pysp.pyro.smanager_pyro
#      17 import pysp.annotations
#      18 import pysp.solutionioextensions
#
# File ~/projects/LOGOS/src/contrib/pysp/pyro/smanager_pyro.py:21
#      18 except:
#      19     import pickle
# ---> 21 import pyutilib.pyro
#      22 from pyutilib.pyro import using_pyro4, TaskProcessingError
#      23 from pyomo.opt.base import OptSolver, SolverFactory
#
# ModuleNotFoundError: No module named 'pyutilib'

# %% [markdown]
# ## Initialize testing schedule

# %%
start = Activity("start", 5)
a = Activity("a", 2)
b = Activity("b", 3)
c = Activity("c", 3)
d = Activity("d", 4)
e = Activity("e", 3)
f = Activity("f", 6)
g = Activity("g", 3)
h = Activity("h", 6)
end = Activity("end", 2)

graph = {start: [a, d, f], 
         a: [b], 
         b: [c], 
         c: [g, h], 
         d: [e], 
         e: [c], 
         f: [c],
         g: [end],
         h: [end], 
         end:[]}

outageStartTime =  datetime(2025, 4, 25, 8)

pert = Pert(graph, startTime=outageStartTime)
pert.returnGraphSymbolic()

# %%
pert.returnScheduleEndTime()

# %%
from IPython.display import Image 

Image(url="model1.png")

# %% [markdown]
# ## Determine CP

# %%
pert.getCriticalPathSymbolic()

# %%
Image(url="model1A.png")

# %% [markdown]
# ## Determine paths parallel to CP

# %%
paths = pert.getAllPathsParallelToCP()
for path in paths:
    print(pert.returnPathSymbolic(path))

# %% [markdown]
# ## Determine subpaths

# %%
subpaths = pert.getSubpathsParalleltoCP()
for subpath in subpaths:
    print(pert.returnPathSymbolic(subpath))

# %% [markdown]
# ## Simplify schedule

# %%
pertRed = pert.simplifyGraph()
pertRed.returnGraphSymbolic()

# %%
for node in pertRed.returnGraph():
    print(node.returnName() + ': ' , end =" ")
    for sub in node.returnSubActivities():
        print(' ' + sub.returnName(), end =" ")
    print()

# %%
pertRed.getCriticalPathSymbolic()

# %%
pert.saveScheduleToJsn()
