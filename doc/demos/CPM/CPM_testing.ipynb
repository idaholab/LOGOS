# %% [markdown]
# # Notebook designed to test PERT class methods (Model 1)

# %%
import sys
sys.path.insert(0, '../../../src/CPM/')
sys.path.insert(0, '../../../src/CapitalInvestments/PyomoModels/')

from PertMain2 import Pert, Activity
import copy
from datetime import datetime, time
import json
# Out:
# /Users/mandd/projects/LOGOS/doc/demos/CPM
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.insert(0, '../../../src/CPM/')
# ----> 4 from PertMain2 import Pert, Activity
#       5 import copy
#       6 from datetime import datetime, time
#
# File ~/projects/LOGOS/doc/demos/CPM/../../../src/CPM/PertMain2.py:17
#      14 import os
#      15 print(os.getcwd())
# ---> 17 from ..CapitalInvestments.PyomoModels.SingleKnapsack import SingleKnapsack
#      19 class Activity:
#      20   """
#      21     This is the base class for a single activity
#      22     Extended from the original development of Nofar Alfasi
#      23     Source https://github.com/nofaralfasi/PERT-CPM-graph
#      24   """
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# ## Initialize testing schedule

# %%
start = Activity("start", 5)
a = Activity("a", 2)
b = Activity("b", 3)
c = Activity("c", 3)
d = Activity("d", 4)
e = Activity("e", 3)
f = Activity("f", 6)
g = Activity("g", 3)
h = Activity("h", 6)
end = Activity("end", 2)

graph = {start: [a, d, f], 
         a: [b], 
         b: [c], 
         c: [g, h], 
         d: [e], 
         e: [c], 
         f: [c],
         g: [end],
         h: [end], 
         end:[]}

outageStartTime =  datetime(2025, 4, 25, 8)

pert = Pert(graph, startTime=outageStartTime)
pert.returnGraphSymbolic()

# %%
pert.returnScheduleEndTime()

# %%
from IPython.display import Image 

Image(url="model1.png")

# %% [markdown]
# ## Determine CP

# %%
pert.getCriticalPathSymbolic()

# %%
Image(url="model1A.png")

# %% [markdown]
# ## Determine paths parallel to CP

# %%
paths = pert.getAllPathsParallelToCP()
for path in paths:
    pert.returnPathSymbolic(path)

# %% [markdown]
# ## Determine subpaths

# %%
subpaths = pert.getSubpathsParalleltoCP()
for subpath in subpaths:
    pert.printPathSymbolic(subpath)

# %% [markdown]
# ## Simplify schedule

# %%
pertRed = pert.simplifyGraph()
pertRed.returnGraphSymbolic()

# %%
for node in pertRed.returnGraph():
    print(node.returnName() + ': ' , end =" ")
    for sub in node.returnSubActivities():
        print(' ' + sub.returnName(), end =" ")
    print()

# %%
pertRed.getCriticalPathSymbolic()

# %%
pert.saveScheduleToJsn()
